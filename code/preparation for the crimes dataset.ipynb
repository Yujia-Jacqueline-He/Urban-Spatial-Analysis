# %%
import pandas as pd

# %%
df = pd.read_csv("Crime Incident Reports (August 2015 - To Date) (Source - New System).csv")

df = df[~df['Lat'].isna()].reset_index(drop = True)

df = df[df["YEAR"] == 2018]

df
# Out:
# F:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 780         I192077559          3115  Investigate Person
# 943         I192077332           619             Larceny
# 1461        I192076660          2629          Harassment
# 2429        I192075386          2629          Harassment
# 2475        I192075335          3208       Property Lost
# ...                ...           ...                 ...
# 397789   I070720870-00           637             Larceny
# 397790   I070720870-00           637             Larceny
# 397791   I060168073-00          3125     Warrant Arrests
# 397792   I060168073-00          1864      Drug Violation
# 397793   I060168073-00          1864      Drug Violation
#
# ...

# %%
df_new = df[df.columns[[2,6,14,15]]].reset_index(drop = True)
df_new.groupby(df_new["OFFENSE_CODE_GROUP"]).count()
# Out:
#                                   SHOOTING   Lat  Long
# OFFENSE_CODE_GROUP
# Aggravated Assault                     151  2312  2312
# Aircraft                                 0    14    14
# Arson                                    0    17    17
# Assembly or Gathering Violations         0   188   188
# Auto Theft                               0  1253  1253
# Auto Theft Recovery                      0   323   323
# Ballistics                              18   262   262
# Bomb Hoax                                0    33    33
# Commercial Burglary                      0   315   315
# Confidence Games                         0   845   845
# Counterfeiting                           0   404   404
# Criminal Harassment                      0    41    41
# Disorderly Conduct                       1   582   582
# Drug Violation                           7  4190  4190
# Embezzlement                             0    93    93
# Evading Fare                             0   108   108
# ...

# %%
crimes_types = ['Aggravated Assault', 'Aircraft', 'Arson', 'Assembly or Gathering Violations', 'Auto Theft', 'Auto Theft Recovery', 
                'Ballistics', 'Bomb Hoax', 'Commercial Burglary', 'Criminal Harassment', 'Disorderly Conduct', 'Drug Violation', 'Explosives', 
                'Firearm Violations', 'HOME INVASION', 'Harassment', 'Homicide', 'Manslaughter', 'Offenses Against Child / Family', 
                'Residential Burglary', 'Robbery', 'Search Warrants', 'Simple Assault', 'Vandalism', 'Warrant Arrests']

# %%
for i in range(len(crimes_types)):
    crimes_type = crimes_types[i]
    df_new[crimes_type] = (df_new['OFFENSE_CODE_GROUP'] == crimes_type).astype(int)

# %%
df_no_select = df_new.copy()
for type in crimes_types:
    df_no_select = df_no_select[df_no_select[type] != 1]

df_select = df_new.drop(df_nonselect.index.to_list()).iloc[:,2:].drop(df_select[df_select.Long>-60].index)

# %%
df_select.to_csv("Crime Incident Reports (2018) (Source - New System) (selected types of crimes).csv")
